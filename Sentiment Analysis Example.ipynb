# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from tqdm import tqdm

# %%
df = pd.read_csv('E:\Downloads\Reviews.csv')

# %% [markdown]
# Basic ADE

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
print(df.shape)
# Out:
# (568454, 10)

# %%
#column Score
df['Score']
# Out:
# 0         5
# 1         1
# 2         4
# 3         2
# 4         5
#          ..
# 568449    5
# 568450    2
# 568451    5
# 568452    5
# 568453    5
# Name: Score, Length: 568454, dtype: int64

# %%
#number of time each score occurs
df['Score'].value_counts()
# Out:
# 5    363122
# 4     80655
# 1     52268
# 3     42640
# 2     29769
# Name: Score, dtype: int64

# %%
#sorting the scors
df['Score'].value_counts().sort_index()
# Out:
# 1     52268
# 2     29769
# 3     42640
# 4     80655
# 5    363122
# Name: Score, dtype: int64

# %%
#bar plot
ax=df['Score'].value_counts().sort_index().plot(kind='bar',title='Count of Reviews by Stars',figsize=(10,5))
ax.set_xlabel("Review Stars")
plt.show()

# %% [markdown]
# Basic NLTK

# %%
example=df['Text'][50]
print(example)
# Out:
# This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go.

# %%
tokens = nltk.word_tokenize(example)
print(tokens)
# Out:
# ['This', 'oatmeal', 'is', 'not', 'good', '.', 'Its', 'mushy', ',', 'soft', ',', 'I', 'do', "n't", 'like', 'it', '.', 'Quaker', 'Oats', 'is', 'the', 'way', 'to', 'go', '.']

# %%
tagged=nltk.pos_tag(tokens)
tagged[:10]
# Out:
# [('This', 'DT'),
#  ('oatmeal', 'NN'),
#  ('is', 'VBZ'),
#  ('not', 'RB'),
#  ('good', 'JJ'),
#  ('.', '.'),
#  ('Its', 'PRP$'),
#  ('mushy', 'NN'),
#  (',', ','),
#  ('soft', 'JJ')]

# %% [markdown]
# Vader Sentiment Scoring
# SentimentIntensityAnalyzer is used to get negative, positive and nutral scores of a text
# We can visualize the completion of the loop on the console screen with the progress bar. We can do so by using an external python package named tqdm. The tqdm() method wraps around the iterable list of the loop and automatically detects and makes the progress bar on the console.

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm
sia=SentimentIntensityAnalyzer()

# %%
sia.polarity_scores('I am so happy!')
# Out:
# {'neg': 0.0, 'neu': 0.318, 'pos': 0.682, 'compound': 0.6468}

# %%
sia.polarity_scores(example)
# Out:
# {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compound': -0.5448}

# %%
# Run polarity _score through all of the data
#DataFrame.iterrows()[source] Iterate over DataFrame rows as (index, Series) pairs
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    text = row['Text']
    myid = row['Id']
    res[myid] = sia.polarity_scores(text)
# Out:
# ...
#   4%|███                                                                       | 23880/568454 [00:45<17:51, 508.19it/s]
# ...
# ...
#  32%|███████████████████████▏                                                 | 180279/568454 [05:51<12:36, 512.79it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [22], in <cell line: 4>()
#       5 text = row['Text']
#       6 myid = row['Id']
# ----> 7 res[myid] = sia.polarity_scores(text)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\sentiment\vader.py:375, in SentimentIntensityAnalyzer.polarity_scores(self, text)
#     372 valence = 0
#     373 i = words_and_emoticons.index(item)
#     374 if (
# --> 375     i < len(words_and_emoticons) - 1
#     376     and item.lower() == "kind"
#     377     and words_and_emoticons[i + 1].lower() == "of"
#     378 ) or item.lower() in self.constants.BOOSTER_DICT:
# ...

# %%
vaders = pd.DataFrame(res).T
vaders = vaders.reset_index().rename(columns={'index': 'Id'})
vaders = vaders.merge(df, how='left')

# %%
vaders.head()
# Out:
#    Id    neg    neu    pos  compound   ProductId          UserId  \
# 0   1  0.000  0.695  0.305    0.9441  B001E4KFG0  A3SGXH7AUHU8GW
# 1   2  0.138  0.862  0.000   -0.5664  B00813GRG4  A1D87F6ZCVE5NK
# 2   3  0.091  0.754  0.155    0.8265  B000LQOCH0   ABXLMWJIXXAIN
# 3   4  0.000  1.000  0.000    0.0000  B000UA0QIQ  A395BORC6FGVXV
# 4   5  0.000  0.552  0.448    0.9468  B006K2ZZ7K  A1UQRSCLF8GW1T
#
#                        ProfileName  HelpfulnessNumerator  \
# 0                       delmartian                     1
# 1                           dll pa                     0
# 2  Natalia Corres "Natalia Corres"                     1
# 3                             Karl                     3
# 4    Michael D. Bigham "M. Wassir"                     0
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
# ...

# %% [markdown]
# Plot vaders results

# %%
sns.barplot(data=vaders,x='Score',y='compound')
ax.set_title('Compound score by Amazon')
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 3))
sns.barplot(data=vaders, x='Score', y='pos', ax=axs[0])
sns.barplot(data=vaders, x='Score', y='neu', ax=axs[1])
sns.barplot(data=vaders, x='Score', y='neg', ax=axs[2])
axs[0].set_title('Positive')
axs[1].set_title('Neutra')
axs[2].set_title('Negative')
plt.tight_layout()
plt.show()
